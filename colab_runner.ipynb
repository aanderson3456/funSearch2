# %% [markdown]
# # SnakyNet AlphaZero Training Runner (Git Auto-Sync)
# This notebook automatically clones and pulls the latest training code directly from GitHub.
# **You never need to upload or download another `.ipynb` file again!** Just run all cells.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !rm -rf /content/funSearch2
# !git clone https://github.com/aanderson3456/funSearch2.git /content/funSearch2
# %cd /content/funSearch2/FS2
# !python train_colab_NNv3.py
